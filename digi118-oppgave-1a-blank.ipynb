# %% [markdown]
# # DIGI118 Oppgave 1a
# ---

# %% [markdown]
# **Lag først en kopi av denne notatboken ved hjelp av knappen øverst til høyre i dette vinduet.
# Nå er du klar til å kode i din egen versjon av denne notatboken.
#
# Bruk `bergen_sampled.csv` fra Bergen Bike Share-datasettet. Dette har 5000 datapunkter, som er det maksimale antallet punkter som Vega-Altair kan jobbe med (uten å legge til utvidelser for dette biblioteket).

# %%
# Import libraries
import pandas as pd
import altair as alt
# YOUR CODE HERE

# %%
# Read in data
# YOUR CODE HERE
bike = pd.read_csv("bergen-bike-sharing-dataset-2023/bergen_sampled.csv")
# Preview the dataframe
# YOUR CODE HERE
bike.head()
# Out:
#             start_time             end_time  duration  start_station_id  \
# 0  2023-05-01 10:00:00  2023-05-01 10:00:00       384               639
# 1  2023-05-01 11:00:00  2023-05-01 11:00:00       310                49
# 2  2023-05-01 12:00:00  2023-05-01 12:00:00        99                 3
# 3  2023-05-01 12:00:00  2023-05-01 13:00:00      4359               791
# 4  2023-05-01 13:00:00  2023-05-01 13:00:00      1278               806
#
#        start_station_name  start_station_latitude  start_station_longitude  \
# 0         Frydenbø Marina               60.384467                 5.310008
# 1     Studentsenteret UiB               60.387198                 5.322980
# 2             Grieghallen               60.388197                 5.328564
# 3      Busstasjonen 4 Sør               60.387059                 5.335634
# 4  Dreggsallmenningen Sør               60.397709                 5.322001
#
#    end_station_id  end_station_name  end_station_latitude  \
# ...

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   start_time               5000 non-null   object
#  1   end_time                 5000 non-null   object
#  2   duration                 5000 non-null   int64
#  3   start_station_id         5000 non-null   int64
#  4   start_station_name       5000 non-null   object
#  5   start_station_latitude   5000 non-null   float64
#  6   start_station_longitude  5000 non-null   float64
#  7   end_station_id           5000 non-null   int64
#  8   end_station_name         5000 non-null   object
#  9   end_station_latitude     5000 non-null   float64
#  10  end_station_longitude    5000 non-null   float64
#  11  precipitation            5000 non-null   float64
#  12  temperature              5000 non-null   float64
#  13  wind_speed               5000 non-null   float64
# ...

# %%
# Specify chart title and description
# YOUR CODE HERE
chart_title = alt.Title(
       "Bike sharing in Bergen",
       subtitle="Something something bike sharing subtitle"
)
# Draw a histogram with a chart title and description. Annotate the data type of each field.
# YOUR CODE HERE
bike = alt.Chart(start_time, title=chart_title).mark_line().encode(
    alt.X("Time:T"),
    alt.Y("Air temperature:Q")
)
# Display chart
# YOUR CODE HERE
bike
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       3 chart_title = alt.Title(
#       4        "Bike sharing in Bergen",
#       5        subtitle="Something something bike sharing subtitle"
#       6 )
#       7 # Draw a histogram with a chart title and description. Annotate the data type of each field.
#       8 # YOUR CODE HERE
# ----> 9 bike = alt.Chart(start_time, title=chart_title).mark_line().encode(
#      10     alt.X("Time:T"),
#      11     alt.Y("Air temperature:Q")
#      12 )
#      13 # Display chart
#      14 # YOUR CODE HERE
#      15 bike
#
# NameError: name 'start_time' is not defined

# %%
# Save the chart to Kaggle's Output working folder in order to download it.
# YOUR CODE HERE

# %% [markdown]
# ---
# # Ressurser
# - [DIGI118 Modul 0: Heisann, Python!](https://www.kaggle.com/code/lauragarrison/digi118-h24-modul-0-heisann-python)
# - [DIGI118 Module 0: Heisann, Pandas!](https://www.kaggle.com/code/lauragarrison/digi118-h24-modul-0-heisann-pandas)
# - [DIGI118 Modul 1: Heisann, Altair!](https://www.kaggle.com/code/lauragarrison/digi118-modul-1-heisann-altair)
# - Pandas-dokumentasjon: https://pandas.pydata.org/docs/reference/index.html
# - Altair-dokumentasjon: https://altair-viz.github.io/user_guide/api.html
# - Eksempler på Altair-diagrammer, inkludert histogrammer: https://altair-viz.github.io/gallery
