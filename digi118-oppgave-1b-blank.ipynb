# %% [markdown]
# # DIGI118 Oppgave 1b
# ---

# %% [markdown]
# **Lag først en kopi av denne notatboken ved hjelp av knappen øverst til høyre i dette vinduet. Nå er du klar til å kode i din egen versjon av denne notatboken.**

# %%
#########################################
# Data - du kan overføre noe kode fra Oppgave 1a 
#########################################

# Importer biblioteker
# KODEN DIN HER

# Les inn data og bearbeid data ved behov.
# KODEN DIN HER

# Forhåndsvis datarammen
# KODEN DIN HER

# %%
#########################################
# Histogram - tilpass diagrammet ditt fra Oppgave 1a 
#########################################

# Angi en diagramtittel og beskrivelse, nå med egendefinert skriftstørrelse og justering.
# KODEN DIN HER

# Tegn et histogram med en diagramtittel og beskrivelse. Angi datatypen for hvert felt.
# Tilpass aksetitlene, merkefargene og høyden/bredden på diagrammet.
# KODEN DIN HER

# Vis diagrammet
# KODEN DIN HER

# %%
#########################################
# Lagdelt prikkplott - lag et nytt, spesialtilpasset diagram for Oppgave 1b!
#########################################

# Angi en diagramtittel og beskrivelse med egendefinert skriftstørrelse og justering.
# KODEN DIN HER

# Tegn et lagdelt prikkdiagram for totalt antall turer som starter og slutter ved hver stasjon.
# Tilpass aksetitlene, aksesorteringsrekkefølgen, merkestørrelse og -farger samt diagrammets generelle høyde/bredde.
# Husk å ta med diagramtittelen og beskrivelsen vi spesifiserte ovenfor!

# Tegn først de individuelle punktplottene
# KODEN DIN HER

# Legg de individuelle diagrammene i lag
# KODEN DIN HER

# Vis det lagdelte diagrammet
# KODEN DIN HER

# %%
# Kombiner diagrammene horisontalt
# KODEN DIN HER

# %%
# Lagre de to diagrammene i Kaggles Output-arbeidsmappe for å kunne laste den ned.
# KODEN DIN HER

# %% [markdown]
# ---
# ### OBS: Denne notatboken trenger ikke å sendes inn til oss.
# Koden du har skrevet her skal du overføre til neste ukes notatbok, og til slutt skal du sende inn en endelig notatbok som inneholder all koden du har skrevet for å lage den endelige dashbordvisualiseringen for dette kurset.
#
# # Resources
# - [DIGI118 Modul 0: Heisann, Python!](https://www.kaggle.com/code/lauragarrison/digi118-h24-modul-0-heisann-python)
# - [DIGI118 Modul 0: Heisann, Pandas!](https://www.kaggle.com/code/lauragarrison/digi118-h24-modul-0-heisann-pandas)
# - [DIGI118 Modul 1: Heisann, Altair!](https://www.kaggle.com/code/lauragarrison/digi118-modul-1-heisann-altair)
# - [DIGI118 Modul 2: Det riktige diagrammet for jobben](https://www.kaggle.com/code/amykzhang/digi118-modul-2-det-riktige-diagrammet-for-jobben)
# - Pandas documentation: https://pandas.pydata.org/docs/reference/index.html
# - Altair documentation: https://altair-viz.github.io/user_guide/api.html
# - Examples of Altair charts, including histograms: https://altair-viz.github.io/gallery
# - List of color names: https://htmlcolorcodes.com/color-names/
